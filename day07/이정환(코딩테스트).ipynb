# %%
## file:이정환 코딩테스트

# %%
## 1번문제

def StFull():
    global SIZE, stack, top
    if (top >= SIZE -1):
        return True
    else:
        return False
    
def StEmpty():
    global SIZE, stack, top
    if (top == -1) :
        return True
    else :
        return False

def push(data):
    global SIZE, stack, top
    if (StFull()) :
        print("Stack is Full")
        return
    top += 1
    stack[top] = data

def pop():
    global SIZE, stack, top
    if StEmpty():
        print("Stack is Empty")
        return None
    data = stack[top]
    stack[top] = None
    top -= 1  # 수정: top 값을 감소시킴
    return data

def peek():
    global SIZE, stack, top
    if (StEmpty()) :
        print("Stack is Empty")
        return None
    return stack[top]


## 전역변수 선언 부분
SIZE = int(input("Put Stack Size ==> "))
stack = [None for _ in range(SIZE)]
top = -1

# 메인 코드 부분
if __name__ == "__main__":
    select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==>")

    while (select != 'X' and select != 'x'):
        if select == 'I' or select == 'i':
            data = input("입력할 데이터 ==> ")
            push(data)
            print("스택 상태 : ", stack)
        elif select == 'E' or select == 'e':
            data = pop()
            print("추출된 데이터 ==> ", data)
            print("스택 상태 : ", stack)
            
        elif select == 'V' or select == 'v':
            data = peek()
            print("확인된 데이터 ==> ", data)
            print("스택 상태 : ", stack)
        else:
            print("입력이 잘못됨")

        select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==>")

    print("End of Program")
# Out:
# 스택 상태 :  ['1', None, None]
# 스택 상태 :  ['1', '2', None]
# 스택 상태 :  ['1', '2', '3']
# 확인된 데이터 ==>  3
# 스택 상태 :  ['1', '2', '3']
# Stack is Full
# 스택 상태 :  ['1', '2', '3']
# 추출된 데이터 ==>  3
# 스택 상태 :  ['1', '2', None]
# 추출된 데이터 ==>  2
# 스택 상태 :  ['1', None, None]
# 추출된 데이터 ==>  1
# 스택 상태 :  [None, None, None]
# End of Program

# %% [markdown]
# 2. P269 유명 맛집 대기줄 구현하기 문제를 while True:문을 사용하여 동적으로 입력을 받는 프로그램으로 변경작성하시오.

# %%
## 함수 선언 부분
def QueFull():
    global SIZE, queue, front, rear
    if rear == SIZE - 1:
        return True
    else:
        return False
    
def QueEmpty():
    global SIZE, queue, front, rear
    if rear == -1:  # 수정: rear가 -1인지 확인
        return True
    else:
        return False
    
def enQue(data):
    global SIZE, queue, front, rear
    if QueFull():
        print("Queue is Full")
        return
    rear += 1  # 수정: rear 변수를 사용하여 데이터를 추가
    queue[rear] = data

def deQue():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    data = queue[front+1]
    for i in range(front+1, rear):
        queue[i] = queue[i+1]  # 모든 데이터를 한 칸씩 앞으로 이동
    queue[rear] = None  # rear 위치의 데이터 제거
    rear -= 1  # rear 값 감소
    return data

def peek():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    return queue[front+1]

## 전역변수 선언 부분
SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

## main code
if __name__ == "__main__":
    enQue('정국')
    enQue('뷔')
    enQue('지민')
    enQue('진')
    enQue('슈가')
    print("대기 줄 상태 => ", queue)

    for _ in range(rear+1):
        print(deQue(), '님 식당 들어가자')
        print("대기 줄 상태", queue)

    print("End of 식당")
# Out:
# 대기 줄 상태 =>  ['정국', '뷔', '지민', '진', '슈가']
# 정국 님 식당 들어가자
# 대기 줄 상태 ['뷔', '지민', '진', '슈가', None]
# 뷔 님 식당 들어가자
# 대기 줄 상태 ['지민', '진', '슈가', None, None]
# 지민 님 식당 들어가자
# 대기 줄 상태 ['진', '슈가', None, None, None]
# 진 님 식당 들어가자
# 대기 줄 상태 ['슈가', None, None, None, None]
# 슈가 님 식당 들어가자
# 대기 줄 상태 [None, None, None, None, None]
# End of 식당

# %%
## 2번문제 변형 -1
## 함수 선언 부분
def QueFull():
    global SIZE, queue, front, rear
    if rear == SIZE - 1:
        return True
    else:
        return False
    
def QueEmpty():
    global SIZE, queue, front, rear
    if rear == -1:  # 수정: rear가 -1인지 확인
        return True
    else:
        return False
    
def enQue(data):
    global SIZE, queue, front, rear
    if QueFull():
        print("Queue is Full")
        return
    rear += 1  # 수정: rear 변수를 사용하여 데이터를 추가
    queue[rear] = data

def deQue():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    data = queue[front+1]
    for i in range(front+1, rear):
        queue[i] = queue[i+1]  # 모든 데이터를 한 칸씩 앞으로 이동
    queue[rear] = None  # rear 위치의 데이터 제거
    rear -= 1  # rear 값 감소
    return data

def peek():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    return queue[front+1]

## 전역변수 선언 부분
SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

## main code
if __name__ == "__main__":
    while True:
        select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==>")

        if select == 'X' or select == 'x':
            print("End of 식당")
            break

        if select == 'I' or select == 'i':
            data = input("입력할 데이터 ==> ")
            enQue(data)
            print("대기 줄 상태 => ", queue)
        elif select == 'E' or select == 'e':
            data = deQue()
            if data is not None:
                print(data, '님 식당 들어가자')
            print("대기 줄 상태", queue)
        elif select == 'V' or select == 'v':
            data = peek()
            if data is not None:
                print("확인된 데이터 ==> ", data)
            print("대기 줄 상태", queue)
        else:
            print("입력이 잘못됨")
# Out:
# 대기 줄 상태 =>  ['뷔 ', None, None, None, None]
# 입력이 잘못됨
# 대기 줄 상태 =>  ['뷔 ', '정국', None, None, None]
# 입력이 잘못됨
# 입력이 잘못됨
# 대기 줄 상태 =>  ['뷔 ', '정국', 'ria', None, None]
# 대기 줄 상태 =>  ['뷔 ', '정국', 'ria', 'rain', None]
# 대기 줄 상태 =>  ['뷔 ', '정국', 'ria', 'rain', 'asd']
# End of 식당

# %%
## 2번 - 2 변형

## 함수 선언 부분
def QueFull():
    global SIZE, queue, front, rear
    if rear == SIZE - 1:
        return True
    else:
        return False
    
def QueEmpty():
    global SIZE, queue, front, rear
    if rear == -1:  # 수정: rear가 -1인지 확인
        return True
    else:
        return False
    
def enQue(data):
    global SIZE, queue, front, rear
    if QueFull():
        print("Queue is Full")
        return
    rear += 1  # 수정: rear 변수를 사용하여 데이터를 추가
    queue[rear] = data

def deQue():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    data = queue[front+1]
    for i in range(front+1, rear):
        queue[i] = queue[i+1]  # 모든 데이터를 한 칸씩 앞으로 이동
    queue[rear] = None  # rear 위치의 데이터 제거
    rear -= 1  # rear 값 감소
    return data

def peek():
    global SIZE, queue, front, rear
    if QueEmpty():
        print("Queue is Empty")
        return None
    return queue[front+1]

## 전역변수 선언 부분
SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

## main code
if __name__ == "__main__":
    while True:
        command = input("대기 줄에 추가할 이름을 입력하거나, 큐에서 뺄 이름을 입력하세요 ('q' 입력 시 종료): ")
        if command == 'q':
            break
        elif command == '':  # 입력이 없는 경우 pass
            pass
        elif command == 'deQue':  # deQue 명령인 경우
            print(deQue(), '님 식당에 입장합니다.')
        else:
            enQue(command)
            print(command, '님이 대기 줄에 추가되었습니다.')
        print("대기 줄 상태:", queue)

    print("End of 식당")
# Out:
# 뷔 님이 대기 줄에 추가되었습니다.
# 대기 줄 상태: ['뷔', None, None, None, None]
# 정국 님이 대기 줄에 추가되었습니다.
# 대기 줄 상태: ['뷔', '정국', None, None, None]
# changwoo  님이 대기 줄에 추가되었습니다.
# 대기 줄 상태: ['뷔', '정국', 'changwoo ', None, None]
# rain  님이 대기 줄에 추가되었습니다.
# 대기 줄 상태: ['뷔', '정국', 'changwoo ', 'rain ', None]
# sunny 님이 대기 줄에 추가되었습니다.
# 대기 줄 상태: ['뷔', '정국', 'changwoo ', 'rain ', 'sunny']
# End of 식당

# %% [markdown]
# 3. P309 편의점 판매된 물건 목록 출력하기 문제 역시 while True: 문으로 동적으로 입력받는 프로그램으로 변경하시오.

# %%
import random

# %%
# 3번 책에 쓴것

import random
## 함수 선언
class TreeNode():
    def __init__(self):
        self.left = None
        self.data = None
        self.right = None

## 전역변수 선언 부분
memory = []
root = None
dataAry = ['banana milk', 'Coffee', 'Candy', '도시락', 'Water', 'Kimbap', 'Kimbap']
sellAry = [random.choice(dataAry) for _ in range(20)]

print('오늘 판매된 물건(중복O) --> ', sellAry)

## 메인 코드 부분
node = TreeNode()
node.data = sellAry[0]
root = node
memory.append(node)
for name in sellAry[1:]:

    node = TreeNode()
    node.data = name

    current = root
    while True:
        if name == current.data:
            break
        if name < current.data:
            if current.left == None:
                current.left = node
                memory.append(node)
                break
            current = current.left
        else:
            if current.right == None:
                current.right = node
                memory.append(node)
                break
            current = current.right

print("이진 탐색 트리 구성 완료!")

def preorder(node):
    if node == None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print('오늘 판매된 물건(중복X) --> ', end = ' ')
preorder(root)
# Out:
# 오늘 판매된 물건(중복O) -->  ['Kimbap', '도시락', 'Water', 'Candy', 'Coffee', '도시락', 'banana milk', 'Kimbap', 'Water', '도시락', 'Coffee', '도시락', 'Candy', 'banana milk', 'Coffee', 'banana milk', 'Candy', 'Water', 'Kimbap', 'Kimbap']
# 이진 탐색 트리 구성 완료!
# 오늘 판매된 물건(중복X) -->  Kimbap Candy Coffee 도시락 Water banana milk

# %%
## 3번 - 1 While True: 추가
import random

## 함수 선언
class TreeNode():
    def __init__(self):
        self.left = None
        self.data = None
        self.right = None

## 전역변수 선언 부분
memory = []
root = None
dataAry = ['banana milk', 'Coffee', 'Candy', '도시락', 'Water', 'Kimbap', 'Coffee']
sellAry = [random.choice(dataAry) for _ in range(20)]

print('오늘 판매된 물건(중복O) --> ', sellAry)

## 메인 코드 부분
node = TreeNode()
node.data = sellAry[0]
root = node
memory.append(node)
for name in sellAry[1:]:

    node = TreeNode()
    node.data = name

    current = root
    while True:
        if name == current.data:
            break
        if name < current.data:
            if current.left == None:
                current.left = node
                memory.append(node)
                break
            current = current.left
        else:
            if current.right == None:
                current.right = node
                memory.append(node)
                break
            current = current.right

print("이진 탐색 트리 구성 완료!")

def preorder(node):
    if node == None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print('오늘 판매된 물건(중복X) --> ', end=' ')
preorder(root)

## 추가 코드: 무한 루프를 통한 데이터 추가 및 출력
while True:
    new_item = input("\n추가할 물건 이름을 입력하세요 ('q' 입력 시 종료): ")
    if new_item == 'q':
        break
    else:
        node = TreeNode()
        node.data = new_item

        current = root
        while True:
            if new_item == current.data:
                break
            if new_item < current.data:
                if current.left == None:
                    current.left = node
                    memory.append(node)
                    break
                current = current.left
            else:
                if current.right == None:
                    current.right = node
                    memory.append(node)
                    break
                current = current.right

        print("물건 추가 완료!")
        print('오늘 판매된 물건(중복X) --> ', end=' ')
        preorder(root)

print("End of 프로그램")
# Out:
# 오늘 판매된 물건(중복O) -->  ['Water', 'banana milk', '도시락', '도시락', '도시락', 'Coffee', 'Coffee', 'Candy', 'banana milk', 'Water', 'Candy', 'banana milk', 'Candy', 'Kimbap', 'Candy', 'Water', 'Kimbap', '도시락', 'Coffee', 'Water']
# 이진 탐색 트리 구성 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy Kimbap banana milk 도시락 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy Kimbap banana milk 도시락 cookie 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy Kimbap banana milk 도시락 cookie 담배 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy Kimbap banana milk 도시락 cookie 담배 소주 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy Kimbap banana milk 도시락 cookie 담배 소주 물 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy  Kimbap banana milk 도시락 cookie 담배 소주 물 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy  Kimbap banana milk 도시락 cookie 담배 소주 물 물건 추가 완료!
# 오늘 판매된 물건(중복X) -->  Water Coffee Candy  Kimbap banana milk 도시락 cookie 담배 소주 물 물건 추가 완료!
# ...
